# %% [markdown]
# <a href="https://colab.research.google.com/github/Vibhutideshmukh/python../blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
# Our first series
number_series = pd.Series([2,3,5,6,8])
print(number_series)
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
number_series = pd.Series([2,3,5,6,8], index = ['a','b','d','e','f'],name = 'Number')
print(number_series)
# Out:
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64

# %%
print(number_series[0])
print(number_series)
# Out:
# 2
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64
# <ipython-input-7-ede16d752d50>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[0])

# %%
some_2D_array = np.random.randint(4,6,(3,4))
first_dataframe = pd.DataFrame(some_2D_array, columns = ['Akshay','Devashish','Divy','Monika'])
print(first_dataframe)
# Out:
#    Akshay  Devashish  Divy  Monika
# 0       4          5     4       4
# 1       5          5     5       4
# 2       4          5     5       4

# %%
import pandas as pd
another_dataframe = pd.DataFrame(some_2D_array, columns = ['A','B','C','D'],index = ['First','Second','Third'])
another_dataframe
# Out:
#         A  B  C  D
# First   4  5  4  4
# Second  5  5  5  4
# Third   4  5  5  4

# %%
series_dict = {'First Series' : pd.Series([10,20,30,40]),
               'Second Series': pd.Series([10,20,30,40])}
df = pd.DataFrame(series_dict) # This line and the next should be unindented
df # This line and the previous should be unindented
# Out:
#    First Series  Second Series
# 0            10             10
# 1            20             20
# 2            30             30
# 3            40             40

# %%
employee_dict = {'Emmployee Name':['Rajeev','Sumit','Aviral'], 'Income': [200000,140000,90000]}
employee_df = pd.DataFrame(employee_dict)
employee_df
# Out:
#   Emmployee Name  Income
# 0         Rajeev  200000
# 1          Sumit  140000
# 2         Aviral   90000

# %%
list_of_lists = [['Amar',10],['Akbar',15],['Anthony',14]]
df = pd.DataFrame(list_of_lists, columns = ['Name','Age'])
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   15
# 2  Anthony   14

# %%
list_of_dicts = [{'a': 2, 'c':3}, {'a':10,'b':20, 'c':30}]
df = pd.DataFrame(list_of_dicts, index = ['First','second'])
df
# Out:
#          a   c     b
# First    2   3   NaN
# second  10  30  20.0

# %%
actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Robert Downey Jr.', 'Chris Evans']
actor_ages = [48,62,54,np.nan]
list_of_tuples = list(zip(actor_names,actor_ages))
actor_df = pd.DataFrame(list_of_tuples, columns = ['Name','Age'])
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
list_of_dicts = [{'a': 1, 'b':2, 'c':3}, {'a':10,'b':20, 'c':30}]
df = pd.DataFrame(list_of_dicts)
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
# Create an array of shape (3,5)
our_array = np.random.randn(3,5)
df = pd.DataFrame(our_array, columns = ['A','B','C','D','E'])
df
# Out:
#           A         B         C         D         E
# 0 -1.483900 -1.277325  0.788527 -0.394714  1.285988
# 1 -0.214352  0.576084 -1.443978  0.955405 -0.407831
# 2 -0.795624 -2.350207  0.688066 -0.998180  0.185806

# %%
list(actor_df.index)
# Out:
# [0, 1, 2, 3]

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0 -1.483900 -1.277325  0.788527 -0.394714  1.285988
# 1 -0.214352  0.576084 -1.443978  0.955405 -0.407831
# 2 -0.795624 -2.350207  0.688066 -0.998180  0.185806

# %%
df.head(1)
# Out:
#         A         B         C         D         E
# 0 -1.4839 -1.277325  0.788527 -0.394714  1.285988

# %%
df.tail(1)
# Out:
#           A         B         C        D         E
# 2 -0.795624 -2.350207  0.688066 -0.99818  0.185806

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list(actor_df.columns)
# Out:
# ['Name', 'Age']

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
df1 = actor_df.rename(columns = {'Name':'Actor Name', 'Age':'Actor Age'}, inplace = False)
df1
# Out:
#              Actor Name  Actor Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       62.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
employee_df
# Out:
#   Emmployee Name  Income
# 0         Rajeev  200000
# 1          Sumit  140000
# 2         Aviral   90000

# %%
employee_df.rename(columns = {'Employee Name': 'Name'}, inplace = True)
employee_df
# Out:
#   Emmployee Name  Income
# 0         Rajeev  200000
# 1          Sumit  140000
# 2         Aviral   90000
